# %%
import pandas as pd
import numpy as np
from pandas import DataFrame
from bs4 import BeautifulSoup
from urllib.request import urlopen
html = urlopen("https://raw.githubusercontent.com/vashineyu/slides_and_others/master/tutorial/examples/imagenet_urls_examples.txt").read().decode('utf-8')

# %%
groups = ["Country1", "Country2", "Country3", "Country4", "Country5", "Country6"]  

num = np.random.randint(low=600,high=1000621,size=6)

dict = {"國家": groups,  
        "人口": num
        }
select_df = pd.DataFrame(dict)
select_df
# Out:
#          國家      人口
# 0  Country1  204943
# 1  Country2  692695
# 2  Country3  427445
# 3  Country4  815200
# 4  Country5  591937
# 5  Country6  549388

# %%
dfs = pd.read_table('https://raw.githubusercontent.com/vashineyu/slides_and_others/master/tutorial/examples/imagenet_urls_examples.txt') 
soup = BeautifulSoup(html, features='lxml')
a = soup.p.getText()
from io import StringIO
TESTDATA = StringIO(a)
df = pd.read_csv(TESTDATA, sep="\t",prefix='x',header=None)
df.columns = ['id', 'link']
df
#df = pd.read_csv(a, sep=" ")
#print(pd.DataFrame(data = a, columns = ['a', 'b']))
# Out:
#                   id                                               link
# 0      n00015388_157  http://farm1.static.flickr.com/145/430300483_2...
# 1      n00015388_238  http://farm2.static.flickr.com/1005/3352960681...
# 2      n00015388_304  http://farm1.static.flickr.com/27/51009336_a96...
# 3      n00015388_327  http://farm4.static.flickr.com/3025/2444687979...
# 4      n00015388_355  http://img100.imageshack.us/img100/3253/forres...
# 5      n00015388_373  http://img172.imageshack.us/img172/4606/napo03...
# 6      n00015388_379  http://fotootjesvanannelies.web-log.nl/olifant...
# 7      n00015388_388  http://www.deweekkrant.nl/images/library/pictu...
# 8      n00015388_442  http://www.porschemania.it/discus/messages/815...
# 9      n00015388_474  http://farm1.static.flickr.com/72/225029238_80...
# 10     n00015388_514  http://farm2.static.flickr.com/1128/1432436038...
# 11     n00015388_671  http://farm4.static.flickr.com/3217/2942611930...
# ...

# %%
df.iloc[0:5,1]
# Out:
# 0    http://farm1.static.flickr.com/145/430300483_2...
# 1    http://farm2.static.flickr.com/1005/3352960681...
# 2    http://farm1.static.flickr.com/27/51009336_a96...
# 3    http://farm4.static.flickr.com/3025/2444687979...
# 4    http://img100.imageshack.us/img100/3253/forres...
# Name: link, dtype: object

# %%
from skimage import io#第5張HTTP404
for i in range(0,5):
    image = io.imread(df.iloc[i,1])
    io.imshow(image)
    io.show()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-94-a9ab4845207b> in <module>()
#       1 from skimage import io
#       2 for i in range(0,5):
# ----> 3     image = io.imread(df.iloc[i,1])
#       4     io.imshow(image)
#       5     io.show()
#
# ~\Anaconda3\lib\site-packages\skimage\io\_io.py in imread(fname, as_gray, plugin, flatten, **plugin_args)
#      59             plugin = 'tifffile'
#      60
# ---> 61     with file_or_url_context(fname) as fname:
#      62         img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      63
#
# ~\Anaconda3\lib\contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# ...
